# %% [markdown]
# # 📈 ดึงราคาหุ้น ด้วย Python using **`yfinance`**

# %%
# !pip install yfinance
# !pip install pandas

# %%
import yfinance as yf
kbank = yf.Ticker("KBANK.BK")
kbank.info
# Out:
# {'address1': '400/22 Phahon Yothin Road',
#  'address2': 'Sam Sen Nai Sub-District Phaya Thai District',
#  'city': 'Bangkok',
#  'zip': '10400',
#  'country': 'Thailand',
#  'phone': '66 2 222 0000',
#  'fax': '66 2 470 1144',
#  'website': 'https://www.kasikornbank.com',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
## ดึงราคาหุ้น
kbank.info["currentPrice"]
# Out:
# 167.0

# %%
kbank.history(period = '1mo') # price in 1 month
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 2025-09-15 00:00:00+07:00  166.5  168.0  165.5  167.0   6309800        0.0
# 2025-09-16 00:00:00+07:00  167.0  167.0  164.0  164.0  16547400        0.0
# 2025-09-17 00:00:00+07:00  165.0  165.0  163.0  163.5  16865300        0.0
# 2025-09-18 00:00:00+07:00  164.0  164.5  162.5  162.5   7800800        0.0
# 2025-09-19 00:00:00+07:00  163.5  165.5  163.0  164.5   6677100        0.0
# 2025-09-22 00:00:00+07:00  165.0  165.5  163.0  163.0   7088000        0.0
# 2025-09-23 00:00:00+07:00  163.5  164.5  162.5  163.0   5782100        0.0
# 2025-09-24 00:00:00+07:00  164.0  165.5  162.0  163.0  10650500        0.0
# 2025-09-25 00:00:00+07:00  164.0  166.5  163.5  166.5   9107200        0.0
# 2025-09-26 00:00:00+07:00  166.5  168.0  165.0  166.0   9942200        0.0
# 2025-09-29 00:00:00+07:00  167.5  169.0  166.5  168.0  10578500        0.0
# ...

# %%
## plot chart
kbank.history(period = '1y')["Close"].plot(color='red');

# %%
kbank.history(period = '1y')["Open"].plot(color='green');

# %%
kbank.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2025, 9, 10),
#  'Earnings Date': [datetime.date(2025, 10, 21)],
#  'Earnings High': 5.37,
#  'Earnings Low': 4.37,
#  'Earnings Average': 4.81744,
#  'Revenue High': 47476000000,
#  'Revenue Low': 45472000000,
#  'Revenue Average': 46901534000}

# %%
kbank.quarterly_income_stmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.962000e-01
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  1.248819e+10
# Reconciled Depreciation                             2.347252e+09
# Net Interest Income                                 3.776700e+10
# Interest Expense                                    6.171000e+09
# Interest Income                                     4.393800e+10
# Normalized Income                                   1.248819e+10
# Net Income From Continuing And Discontinued Ope...  1.248819e+10
# Diluted Average Shares                              2.369328e+09
# Basic Average Shares                                2.369328e+09
# ...
