# %% [markdown]
# # 📩 **Import Module and Load the Dataset: `HR data MNC`**
# \sunsun-datateathyme\

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# read csv file
df = pd.read_csv('HR_Data_MNC_V2.csv')

# %% [markdown]
# # 🎯 **Getting some basic information about the dataset**

# %%
df.head()
# Out:
#    Unnamed: 0 Employee_ID        Full_Name  Department              Job_Title  \
# 0           0  EMP0000001    Joshua Nguyen          IT      Software Engineer
# 1           1  EMP0000002   Julie Williams   Marketing         SEO Specialist
# 2           2  EMP0000003  Alyssa Martinez          HR             HR Manager
# 3           3  EMP0000004  Nicholas Valdez          IT      Software Engineer
# 4           4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator
#
#     Hire_Date                                 Location  Performance_Rating  \
# 0  2011-08-10                       Isaacland, Denmark                   5
# 1  2018-03-02                  Anthonyside, Costa Rica                   2
# 2  2023-03-20         Port Christinaport, Saudi Arabia                   1
# 3  2023-10-12  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024-12-09     Lake Kimberly, Palestinian Territory                   5
#
# ...

# %%
df.tail()
# Out:
#          Unnamed: 0 Employee_ID         Full_Name  Department  \
# 1999995     1999995  EMP1999996      Cody Russell  Operations
# 1999996     1999996  EMP1999997      Tracey Smith          IT
# 1999997     1999997  EMP1999998         Tracy Lee       Sales
# 1999998     1999998  EMP1999999  Michael Roberson          IT
# 1999999     1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title   Hire_Date                 Location  \
# 1999995          Logistics Coordinator  2010-08-31         Casefurt, Serbia
# 1999996              Software Engineer  2021-05-07        Dannyport, Kuwait
# 1999997   Business Development Manager  2024-05-29      Craighaven, Nigeria
# 1999998              Software Engineer  2023-02-14  Jonathanmouth, Djibouti
# 1999999  Talent Acquisition Specialist  2020-11-11    Morganchester, Canada
#
#          Performance_Rating  Experience_Years   Status Work_Mode  Salary_INR
# ...

# %%
df.shape
# Out:
# (2000000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Employee_ID         object
#  2   Full_Name           object
#  3   Department          object
#  4   Job_Title           object
#  5   Hire_Date           object
#  6   Location            object
#  7   Performance_Rating  int64
#  8   Experience_Years    int64
#  9   Status              object
#  10  Work_Mode           object
#  11  Salary_INR          int64
# dtypes: int64(4), object(8)
# memory usage: 183.1+ MB

# %% [markdown]
# # 📩 **Cleaning and Preparing the Data**

# %%
## removing Unnamed: 0  column from the dataframe
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title   Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer  2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist  2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager  2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer  2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator  2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# ...

# %%
## change data-tpye of Hire_Date column
df['Hire_Date'] = pd.to_datetime( df['Hire_Date'] )

# %%
df.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Employee_ID         object
#  1   Full_Name           object
#  2   Department          object
#  3   Job_Title           object
#  4   Hire_Date           datetime64[ns]
#  5   Location            object
#  6   Performance_Rating  int64
#  7   Experience_Years    int64
#  8   Status              object
#  9   Work_Mode           object
#  10  Salary_INR          int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 167.8+ MB

# %%
df['Performance_Rating'].unique()
# Out:
# array([5, 2, 1, 4, 3])

# %%
## count and sort performance rating in descending order
df['Performance_Rating'].value_counts().sort_index(ascending=False)
# Out:
# Performance_Rating
# 5    399727
# 4    400529
# 3    399814
# 2    400174
# 1    399756
# Name: count, dtype: int64

# %%
df['Performance_Rating'].mean()
# Out:
# np.float64(3.0001485)

# %%
## count unique Experience_Years
df['Experience_Years'].nunique()
# Out:
# 16

# %%
df['Experience_Years'].unique()
# Out:
# array([14,  7,  2,  1,  0,  4,  9,  5,  6,  8,  3, 10, 11, 12, 13, 15])

# %%
## plot bar chart
sns.countplot( x = 'Experience_Years', data = df,  palette='tab20c')
plt.title('Distribution of Experience Years')
plt.show()
# Out:
# /tmp/ipython-input-1699304545.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x = 'Experience_Years', data = df,  palette='tab20c')

# %%
df['Experience_Years'].value_counts()
# Out:
# Experience_Years
# 3     200522
# 2     199924
# 4     199866
# 1     199162
# 0     198775
# 6     160410
# 9     160223
# 8     160212
# 5     160112
# 7     159005
# 10     41209
# 13     40149
# 11     40146
# 14     40005
# 12     39709
# 15       571
# Name: count, dtype: int64

# %%
df.select_dtypes(include='object')
# Out:
#         Employee_ID         Full_Name  Department  \
# 0        EMP0000001     Joshua Nguyen          IT
# 1        EMP0000002    Julie Williams   Marketing
# 2        EMP0000003   Alyssa Martinez          HR
# 3        EMP0000004   Nicholas Valdez          IT
# 4        EMP0000005    Joel Hendricks  Operations
# ...             ...               ...         ...
# 1999995  EMP1999996      Cody Russell  Operations
# 1999996  EMP1999997      Tracey Smith          IT
# 1999997  EMP1999998         Tracy Lee       Sales
# 1999998  EMP1999999  Michael Roberson          IT
# 1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title  \
# 0                    Software Engineer
# 1                       SEO Specialist
# 2                           HR Manager
# 3                    Software Engineer
# 4                Logistics Coordinator
# ...                                ...
# 1999995          Logistics Coordinator
# ...

# %%
df.select_dtypes(include='number')
# Out:
#          Performance_Rating  Experience_Years  Salary_INR
# 0                         5                14     1585363
# 1                         2                 7      847686
# 2                         1                 2     1430084
# 3                         1                 1      990689
# 4                         5                 0      535082
# ...                     ...               ...         ...
# 1999995                   3                14      657648
# 1999996                   3                 4     1030109
# 1999997                   5                 1     1313085
# 1999998                   4                 2     1479727
# 1999999                   1                 4      993718
#
# [2000000 rows x 3 columns]

# %% [markdown]
# # 🎯 **Writing the code**
# ✅ **Using this dataset, we answered multiple questions with Python in our Project**

# %% [markdown]
# ### 🌻 **Q1.What is the distribution of Employee Status (Active, Resigned, Retired, Terminated)?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
status = df['Status'].value_counts()
status
# Out:
# Status
# Active        1401558
# Resigned       398660
# Retired         99912
# Terminated      99870
# Name: count, dtype: int64

# %%
type(status)
# Out:
# pandas.core.series.Series

# %%
## create pie chart
status.plot(kind='pie', autopct='%1.1f%%', explode=(0.015,0.015,0.015,0.015))
plt.title('Distribution of Employee Status')
plt.show()

# %% [markdown]
# ### 🌻 **Q2. What is the distribution of work modes (On-site, Remote) ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
work = df['Work_Mode'].value_counts()
work
# Out:
# Work_Mode
# On-site    1199109
# Remote      800891
# Name: count, dtype: int64

# %%
work.plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.title('Distribution of Work Modes')
plt.show()

# %% [markdown]
# ### 🌻 **Q3. How many employees are there in each department?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
df['Department'].value_counts()
# Out:
# Department
# IT            601042
# Sales         400031
# Operations    300095
# Marketing     240081
# Finance       199873
# HR            159119
# R&D            99759
# Name: count, dtype: int64

# %%
sns.countplot( x = 'Department', data = df,  palette='tab20b')
plt.title('Distribution of Department')
plt.show()
# Out:
# /tmp/ipython-input-2516874435.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x = 'Department', data = df,  palette='tab20b')

# %%
df['Job_Title'].value_counts()
# Out:
# Job_Title
# Software Engineer                300358
# Sales Executive                  199982
# Operations Executive             150058
# Data Analyst                     120375
# Marketing Executive              120154
# Account Manager                  119929
# Accountant                       100307
# DevOps Engineer                   90197
# Logistics Coordinator             90188
# HR Executive                      79348
# SEO Specialist                    71692
# Business Development Manager      60233
# IT Manager                        60224
# Financial Analyst                 59815
# Research Scientist                50017
# Talent Acquisition Specialist     47994
# Supply Chain Manager              44935
# Content Strategist                36154
# CTO                               29888
# Product Developer                 29872
# Finance Manager                   29799
# HR Manager                        23841
# Sales Director                    19887
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot( x = 'Job_Title', data = df, palette='mako')
plt.title('Distribution of Job Title')
plt.xticks(rotation='vertical')

plt.show()
# Out:
# /tmp/ipython-input-2111058339.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x = 'Job_Title', data = df, palette='mako')

# %% [markdown]
# ### 🌻 **Q4. What is the average salary by Department ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
# calculates the average salary for each department
df.groupby('Department')['Salary_INR'].mean()
# Out:
# Department
# Finance       9.404117e+05
# HR            7.438536e+05
# IT            1.129858e+06
# Marketing     7.699362e+05
# Operations    7.546263e+05
# R&D           8.003772e+05
# Sales         7.929579e+05
# Name: Salary_INR, dtype: float64

# %%
## group by department, calculate the mean salary, and convert the result from INR to thousands
dept = df.groupby('Department')['Salary_INR'].mean()/1000
dept
# Out:
# Department
# Finance        940.411743
# HR             743.853561
# IT            1129.858151
# Marketing      769.936152
# Operations     754.626253
# R&D            800.377157
# Sales          792.957860
# Name: Salary_INR, dtype: float64

# %%
## sort the calculated average salaries for each department in descending order
dept_sort = dept.sort_values(ascending=False)

dept_sort
# Out:
# Department
# IT            1129.858151
# Finance        940.411743
# R&D            800.377157
# Sales          792.957860
# Marketing      769.936152
# Operations     754.626253
# HR             743.853561
# Name: Salary_INR, dtype: float64

# %%
## create a bar plot to visualize the average salary by department
dept_sort.plot(x = dept.index, y = dept.values, kind = 'bar', color = 'salmon', legend = True , width = 0.8)
plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.show()

# %% [markdown]
# ### 🌻 **Q5. Which job title has the highest average salary ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
## calculates the average salary for each job title
salary_avg = df.groupby('Job_Title')['Salary_INR'].mean()/1000

salary_avg
# Out:
# Job_Title
# Account Manager                   799.373734
# Accountant                        650.076482
# Brand Manager                     803.127787
# Business Development Manager     1252.016231
# CFO                               795.015873
# CTO                               801.402754
# Content Strategist                800.760030
# Data Analyst                      800.996380
# DevOps Engineer                   799.949184
# Finance Manager                  1743.241525
# Financial Analyst                1051.522903
# HR Director                       800.694437
# HR Executive                      550.548859
# HR Manager                       1252.401915
# IT Manager                       2098.155777
# Innovation Manager                801.870103
# Lab Technician                    800.181468
# Logistics Coordinator             649.631726
# Marketing Executive               798.780404
# Operations Director               798.298093
# Operations Executive              800.350915
# ...

# %%
## sorts and gets the top 10 job titles with the highest average salaries
salary_avg_sort = salary_avg.sort_values(ascending=False).head(10)

salary_avg_sort
# Out:
# Job_Title
# IT Manager                       2098.155777
# Finance Manager                  1743.241525
# HR Manager                       1252.401915
# Business Development Manager     1252.016231
# Software Engineer                1199.260843
# Financial Analyst                1051.522903
# Brand Manager                     803.127787
# Innovation Manager                801.870103
# Talent Acquisition Specialist     801.422237
# CTO                               801.402754
# Name: Salary_INR, dtype: float64

# %%
## create a bar plot to visualize the top 10 average salaries by job title
salary_avg_sort.plot( kind='bar', color='salmon')
plt.title('Average Salary by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Average Salary')
plt.show()

# %% [markdown]
# ### 🌻 **Q6. What is the average salary in different Departments based on Job Title ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
## calculates the average salary for each job title within each department
dept_job = df.groupby(['Department', 'Job_Title'])['Salary_INR'].mean()/1000

dept_job
# Out:
# Department  Job_Title
# Finance     Accountant                        650.076482
#             CFO                               795.015873
#             Finance Manager                  1743.241525
#             Financial Analyst                1051.522903
# HR          HR Director                       800.694437
#             HR Executive                      550.548859
#             HR Manager                       1252.401915
#             Talent Acquisition Specialist     801.422237
# IT          CTO                               801.402754
#             Data Analyst                      800.996380
#             DevOps Engineer                   799.949184
#             IT Manager                       2098.155777
#             Software Engineer                1199.260843
# Marketing   Brand Manager                     803.127787
#             Content Strategist                800.760030
#             Marketing Executive               798.780404
# ...

# %%
## sorts the data first by Department (A-Z) and then by Salary (highest to lowest)
dept_job_sort = dept_job.to_frame().sort_values(by=['Department', 'Salary_INR'], ascending=[True, False])

dept_job_sort
# Out:
#                                            Salary_INR
# Department Job_Title
# Finance    Finance Manager                1743.241525
#            Financial Analyst              1051.522903
#            CFO                             795.015873
#            Accountant                      650.076482
# HR         HR Manager                     1252.401915
#            Talent Acquisition Specialist   801.422237
#            HR Director                     800.694437
#            HR Executive                    550.548859
# IT         IT Manager                     2098.155777
#            Software Engineer              1199.260843
#            CTO                             801.402754
#            Data Analyst                    800.996380
#            DevOps Engineer                 799.949184
# Marketing  Brand Manager                   803.127787
#            Content Strategist              800.760030
#            Marketing Executive             798.780404
# ...

# %% [markdown]
# ### 🌻 **Q7. How many employees Resigned & Terminated in each department ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
## get all unique values in the 'Status' column
df['Status'].unique()
# Out:
# array(['Resigned', 'Active', 'Terminated', 'Retired'], dtype=object)

# %%
## filters the DataFrame to include only employees with a 'Resigned' or 'Terminated' status
resigned_terminated_df = df[df['Status'].isin(['Resigned', 'Terminated'])]

resigned_terminated_df
# Out:
#         Employee_ID         Full_Name  Department              Job_Title  \
# 0        EMP0000001     Joshua Nguyen          IT      Software Engineer
# 8        EMP0000009    Cathy Thompson     Finance      Financial Analyst
# 11       EMP0000012        Kevin Lowe       Sales        Account Manager
# 16       EMP0000017     Robert Martin  Operations  Logistics Coordinator
# 19       EMP0000020    Donald Hoffman   Marketing     Content Strategist
# ...             ...               ...         ...                    ...
# 1999983  EMP1999984      Joshua Ponce       Sales        Account Manager
# 1999985  EMP1999986  Aaron Montgomery   Marketing    Marketing Executive
# 1999986  EMP1999987      Mason Parker  Operations   Operations Executive
# 1999989  EMP1999990      Adrian Lopez       Sales        Sales Executive
# 1999993  EMP1999994     Ashley Fuller          IT        DevOps Engineer
#
#          Hire_Date                      Location  Performance_Rating  \
# ...

# %%
## count the number of resigned and terminated employees in each department
resigned_by_dept = resigned_terminated_df.groupby('Department')['Status'].value_counts()
resigned_by_dept
# Out:
# Department  Status
# Finance     Resigned       40238
#             Terminated      9988
# HR          Resigned       31736
#             Terminated      7861
# IT          Resigned      119852
#             Terminated     29881
# Marketing   Resigned       47793
#             Terminated     12044
# Operations  Resigned       59397
#             Terminated     14884
# R&D         Resigned       19919
#             Terminated      4998
# Sales       Resigned       79725
#             Terminated     20214
# Name: count, dtype: int64

# %% [markdown]
# ### 🌻 **Q8. How does salary vary with years of experience ?**

# %%
## calculates the average salary for each year of experience
avg_salary_by_experience = df.groupby('Experience_Years')['Salary_INR'].mean()
avg_salary_by_experience
# Out:
# Experience_Years
# 0     896737.454775
# 1     895903.759824
# 2     896755.652313
# 3     896861.245240
# 4     897944.573965
# 5     896484.084828
# 6     896012.632467
# 7     895722.673960
# 8     897148.361090
# 9     898482.940577
# 10    895662.027882
# 11    901452.750112
# 12    896432.933416
# 13    898790.197041
# 14    895610.790251
# 15    895647.401051
# Name: Salary_INR, dtype: float64

# %%
## create a line plot to show the relationship between average salary and years of experience
avg_salary_by_experience.plot(kind='line')
plt.title('Average Salary vs. Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Average Salary (INR)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 🌻 **Q9. What is the average performance rating by department ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
PR = df.groupby('Department')['Performance_Rating'].mean()
PR
# Out:
# Department
# Finance       2.996818
# HR            2.995670
# IT            2.998216
# Marketing     3.004736
# Operations    2.996081
# R&D           3.001885
# Sales         3.006362
# Name: Performance_Rating, dtype: float64

# %%
PR.sort_values(ascending=False)
# Out:
# Department
# Sales         3.006362
# Marketing     3.004736
# R&D           3.001885
# IT            2.998216
# Finance       2.996818
# Operations    2.996081
# HR            2.995670
# Name: Performance_Rating, dtype: float64

# %% [markdown]
# ### 🌻 **Q10. Which Country have the highest concentration of employees ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
## extracts the country name from the 'Location' column
df['Country'] = df['Location'].apply( lambda x : str(x.split(',')[1]))

# %%
df.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR                 Country
# ...

# %%
df['Country'].nunique()
# Out:
# 243

# %%
## counts the number of employees in each country
df['Country'].value_counts()
# Out:
# Country
# Congo                     16286
# Korea                     16285
# Sri Lanka                  8409
# Switzerland                8391
# British Virgin Islands     8373
#                           ...
# Indonesia                  7983
# Kazakhstan                 7973
# Montenegro                 7972
# Bhutan                     7971
# Palestinian Territory      7895
# Name: count, Length: 243, dtype: int64

# %% [markdown]
# ### 🌻 **Q11. Is there a correlation between performance rating and salary ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
## calculates the correlation between performance rating and salary
df['Performance_Rating'].corr(df['Salary_INR'])
# Out:
# np.float64(-0.00020919799940916458)

# %%
## alternated Command to show Correlation

df[['Performance_Rating', 'Salary_INR']].corr()
# Out:
#                     Performance_Rating  Salary_INR
# Performance_Rating            1.000000   -0.000209
# Salary_INR                   -0.000209    1.000000

# %% [markdown]
# ### 🌻 **Q12. How has the number of hires changed over time (per year) ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
df['Hire_Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
## extracts the year from the 'Hire_Date' column and inserts it as a new column
## named 'Year' at the 5th position (index 5) in the DataFrame.
df.insert( 5 , 'Year', df['Hire_Date'].dt.year)

# %%
df.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#    Year                                 Location  Performance_Rating  \
# 0  2011                       Isaacland, Denmark                   5
# 1  2018                  Anthonyside, Costa Rica                   2
# 2  2023         Port Christinaport, Saudi Arabia                   1
# 3  2023  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR                 Country
# ...

# %%
## counts the number of employees hired in each year
hire = df.groupby('Year')['Employee_ID'].count()

hire
# Out:
# Year
# 2010     15520
# 2011     40089
# 2012     39765
# 2013     39988
# 2014     40202
# 2015     85984
# 2016    160249
# 2017    160363
# 2018    159658
# 2019    160202
# 2020    175460
# 2021    199366
# 2022    201373
# 2023    198982
# 2024    200001
# 2025    122798
# Name: Employee_ID, dtype: int64

# %%
## create bar chart
hire.plot(kind='bar', color='salmon', alpha=0.8)
plt.title('Number of Hires per Year')
plt.xlabel('Year')
plt.ylabel('Number of Hires')
plt.show()

# %% [markdown]
# ### 🌻 **Q13. Compare salaries of Remote vs. On-site employees — is there a significant difference ?**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  Year  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10  2011
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02  2018
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
## calculates the average salary for each work mode
df.groupby('Work_Mode')['Salary_INR'].mean()
# Out:
# Work_Mode
# On-site    896835.945792
# Remote     896965.326373
# Name: Salary_INR, dtype: float64

# %% [markdown]
# ### 🌻 **Q14. Find the top 10 employees with the highest salary in each department.**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  Year  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10  2011
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02  2018
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
## group by department and then find the top 10 employees with the highest salaries in each group
top_10 = df.groupby('Department').apply(lambda x:x.nlargest(10, "Salary_INR"))
# Out:
# /tmp/ipython-input-3946359043.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_10 = df.groupby('Department').apply(lambda x:x.nlargest(10, "Salary_INR"))

# %%
top_10.head(20)
# Out:
#                    Employee_ID           Full_Name Department  \
# Department
# Finance    888712   EMP0888713   Christopher Sloan    Finance
#            695808   EMP0695809        Todd Rodgers    Finance
#            459273   EMP0459274        Angela Payne    Finance
#            750893   EMP0750894           Nina Lara    Finance
#            780290   EMP0780291   Brittany Thompson    Finance
#            1316795  EMP1316796        Larry Wilson    Finance
#            737507   EMP0737508    Alexis Schroeder    Finance
#            781352   EMP0781353         Sarah Jones    Finance
#            803785   EMP0803786       Jose Anderson    Finance
#            905337   EMP0905338  Jennifer Dominguez    Finance
# HR         223845   EMP0223846         Ethan Jones         HR
#            1068270  EMP1068271         Austin Hall         HR
#            1541972  EMP1541973       Daniel Wilson         HR
#            1861401  EMP1861402      Amanda Everett         HR
# ...

# %%
top_10.tail()
# Out:
#                    Employee_ID           Full_Name Department  \
# Department
# Sales      86194    EMP0086195    Gabrielle Phelps      Sales
#            1116580  EMP1116581     Kimberly Mullen      Sales
#            1760918  EMP1760919  Christopher Farmer      Sales
#            1878661  EMP1878662    Margaret Gardner      Sales
#            1333220  EMP1333221      Benjamin Jones      Sales
#
#                                        Job_Title  Hire_Date  Year  \
# Department
# Sales      86194    Business Development Manager 2015-11-23  2015
#            1116580  Business Development Manager 2025-01-09  2025
#            1760918  Business Development Manager 2013-01-12  2013
#            1878661  Business Development Manager 2025-04-23  2025
#            1333220  Business Development Manager 2017-11-14  2017
#
#                                                       Location  \
# Department
# Sales      86194    New Michaelshire, Central African Republic
# ...

# %% [markdown]
# ##🌻 **Q15. Identify departments with the highest attrition rate (Resigned %)**

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  Year  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10  2011
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02  2018
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
## groups the data by department to count total and resigned employees
dept_counts = df.groupby('Department')['Status'].agg(total_emp = 'count', resigned = lambda x: (x == 'Resigned').sum())

dept_counts
# Out:
#             total_emp  resigned
# Department
# Finance        199873     40238
# HR             159119     31736
# IT             601042    119852
# Marketing      240081     47793
# Operations     300095     59397
# R&D             99759     19919
# Sales          400031     79725

# %%
type(dept_counts)
# Out:
# pandas.core.frame.DataFrame

# %%
## calculate attrition rate

dept_counts['attrition_rate_%'] = (dept_counts['resigned'] / dept_counts['total_emp']) * 100

# %%
dept_counts
# Out:
#             total_emp  resigned  attrition_rate_%
# Department
# Finance        199873     40238         20.131784
# HR             159119     31736         19.944821
# IT             601042    119852         19.940703
# Marketing      240081     47793         19.907031
# Operations     300095     59397         19.792732
# R&D             99759     19919         19.967121
# Sales          400031     79725         19.929705

# %%
## sort by attrition rate (highest first)

dept_counts.sort_values("attrition_rate_%", ascending = False)
# Out:
#             total_emp  resigned  attrition_rate_%
# Department
# Finance        199873     40238         20.131784
# R&D             99759     19919         19.967121
# HR             159119     31736         19.944821
# IT             601042    119852         19.940703
# Sales          400031     79725         19.929705
# Marketing      240081     47793         19.907031
# Operations     300095     59397         19.792732
