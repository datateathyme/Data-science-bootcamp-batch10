# %%
## impost module (library)
import pandas as pd

# %%
## load data from csv file
df = pd.read_csv("penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
## preview first 5 rows
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
## preview last 5 rows
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
## shape of dataframe
df.shape
# Out:
# (344, 7)

# %%
## information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
## select columns
df[['species', 'island', 'sex']].head(10)
# Out:
#   species     island     sex
# 0  Adelie  Torgersen    MALE
# 1  Adelie  Torgersen  FEMALE
# 2  Adelie  Torgersen  FEMALE
# 3  Adelie  Torgersen     NaN
# 4  Adelie  Torgersen  FEMALE
# 5  Adelie  Torgersen    MALE
# 6  Adelie  Torgersen  FEMALE
# 7  Adelie  Torgersen    MALE
# 8  Adelie  Torgersen     NaN
# 9  Adelie  Torgersen     NaN

# %%
## integer location indexing (iloc)
df.iloc[0:3]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE

# %%
df.iloc[[0, 1, 2]]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE

# %%
## select rows and columns
mini_penguins = df.iloc[0:5, [0, 1, 2]]
mini_penguins
# Out:
#   species     island  bill_length_mm
# 0  Adelie  Torgersen            39.1
# 1  Adelie  Torgersen            39.5
# 2  Adelie  Torgersen            40.3
# 3  Adelie  Torgersen             NaN
# 4  Adelie  Torgersen            36.7

# %%
## filter rows by condition
df[ df['island'] == 'Torgersen' ]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
df[ df['bill_length_mm'] < 34 ]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 142  Adelie      Dream            32.1           15.5              188.0
#
#      body_mass_g     sex
# 70        3600.0  FEMALE
# 98        2900.0  FEMALE
# 142       3050.0  FEMALE

# %%
## filter dataframe more than one condition
df[ (df['island'] == 'Torgersen') & (df['bill_length_mm'] < 35) ]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 70  Adelie  Torgersen            33.5           19.0              190.0
# 80  Adelie  Torgersen            34.6           17.2              189.0
#
#     body_mass_g     sex
# 8        3475.0     NaN
# 14       4400.0    MALE
# 18       3325.0  FEMALE
# 70       3600.0  FEMALE
# 80       3200.0  FEMALE

# %%
## or opertor
filter_penguins = df[ (df['island'] == 'Torgersen') | (df['bill_length_mm'] < 35) ]

# %%
## filter with .query()
df.query('island == "Torgersen"') # "island == 'Torgersen'"
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
## filter with .query() more than one condition
df.query('island == "Torgersen" & bill_length_mm < 35 ')
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 70  Adelie  Torgersen            33.5           19.0              190.0
# 80  Adelie  Torgersen            34.6           17.2              189.0
#
#     body_mass_g     sex
# 8        3475.0     NaN
# 14       4400.0    MALE
# 18       3325.0  FEMALE
# 70       3600.0  FEMALE
# 80       3200.0  FEMALE

# %%
## check missing in each column
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
## filter missing values in column sex
df[ df['bill_length_mm'].isna() ]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
## drop na
clean_penguins = df.dropna()
clean_penguins.head(10)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
#
#     body_mass_g     sex
# 0        3750.0    MALE
# 1        3800.0  FEMALE
# 2        3250.0  FEMALE
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# ...

# %%
## fill missing values
top5_penguins = df.head(5)

# %%
avg_value = top5_penguins['bill_length_mm'].mean()
print(avg_value)
# Out:
# 38.9

# %%
top5_penguins =top5_penguins['bill_length_mm'].fillna(value=avg_value)
top5_penguins
# Out:
# 0    39.1
# 1    39.5
# 2    40.3
# 3    38.9
# 4    36.7
# Name: bill_length_mm, dtype: float64

# %%
## sort bill_length_mm low to high , high to low
df.dropna().sort_values(by='bill_length_mm', ascending=False).head(10)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253     Gentoo  Biscoe            59.6           17.0              230.0
# 169  Chinstrap   Dream            58.0           17.8              181.0
# 321     Gentoo  Biscoe            55.9           17.0              228.0
# 215  Chinstrap   Dream            55.8           19.8              207.0
# 335     Gentoo  Biscoe            55.1           16.0              230.0
# 283     Gentoo  Biscoe            54.3           15.7              231.0
# 183  Chinstrap   Dream            54.2           20.8              201.0
# 191  Chinstrap   Dream            53.5           19.9              205.0
# 327     Gentoo  Biscoe            53.4           15.8              219.0
# 181  Chinstrap   Dream            52.8           20.0              205.0
#
#      body_mass_g     sex
# 253       6050.0    MALE
# 169       3700.0  FEMALE
# 321       5600.0    MALE
# 215       4000.0    MALE
# 335       5850.0    MALE
# ...

# %%
## sort multiple columns
df.dropna().sort_values(by=['island', 'bill_length_mm'], ascending=[True, False])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253  Gentoo     Biscoe            59.6           17.0              230.0
# 321  Gentoo     Biscoe            55.9           17.0              228.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 283  Gentoo     Biscoe            54.3           15.7              231.0
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# ..      ...        ...             ...            ...                ...
# 83   Adelie  Torgersen            35.1           19.4              193.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 80   Adelie  Torgersen            34.6           17.2              189.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
#
#      body_mass_g     sex
# 253       6050.0    MALE
# 321       5600.0    MALE
# ...

# %%
## unique values
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
## count values
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
## count more than one columns
result = df[['island', 'species']].value_counts().reset_index()

## rename column
result.columns = ['island', 'species', 'count_n']
result
# Out:
#       island    species  count_n
# 0     Biscoe     Gentoo      124
# 1      Dream  Chinstrap       68
# 2      Dream     Adelie       56
# 3  Torgersen     Adelie       52
# 4     Biscoe     Adelie       44

# %%
import pandas as pd

# %%
df = pd.read_csv("penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
## summarise dataframe
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
## average, mean
df['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
## round number 2 decimal
df['bill_length_mm'].std()

df_std = round(df['bill_length_mm'].std(),2)
df_std
# Out:
# 5.46

# %%
## round
mean_bill_length = df['bill_length_mm'].mean()
df_mean = round(mean_bill_length, 2)
df_mean
# Out:
# np.float64(43.92)

# %%
df['bill_length_mm'].median()
# Out:
# 44.45

# %%
## group by + sum/mean
df.groupby('species')['bill_length_mm'].sum()
# Out:
# species
# Adelie       5857.5
# Chinstrap    3320.7
# Gentoo       5843.1
# Name: bill_length_mm, dtype: float64

# %%
round(df.groupby('species')['bill_length_mm'].mean(),2)
# Out:
# species
# Adelie       38.79
# Chinstrap    48.83
# Gentoo       47.50
# Name: bill_length_mm, dtype: float64

# %%
df.groupby('species')['bill_length_mm'].count()
# Out:
# species
# Adelie       151
# Chinstrap     68
# Gentoo       123
# Name: bill_length_mm, dtype: int64

# %%
## groupby with aggregate function
df.groupby('species')['bill_length_mm'].agg(['min', 'max', 'median', 'mean', 'std'])
# Out:
#             min   max  median       mean       std
# species
# Adelie     32.1  46.0   38.80  38.791391  2.663405
# Chinstrap  40.9  58.0   49.55  48.833824  3.339256
# Gentoo     40.9  59.6   47.30  47.504878  3.081857

# %%
## groupby more than one columns
result = df.groupby(['island', 'species'])['bill_length_mm'] \
  .agg(['min', 'max', 'mean', 'median']) \
  .reset_index()

## write to csv file
result.to_csv("penguins_result.csv")

# %%
## read csv file
pen_df = pd.read_csv("penguins_result.csv")
pen_df.drop(columns=['Unnamed: 0'], inplace=True)
pen_df
# Out:
#       island    species   min   max       mean  median
# 0     Biscoe     Adelie  34.5  45.6  38.975000   38.70
# 1     Biscoe     Gentoo  40.9  59.6  47.504878   47.30
# 2      Dream     Adelie  32.1  44.1  38.501786   38.55
# 3      Dream  Chinstrap  40.9  58.0  48.833824   49.55
# 4  Torgersen     Adelie  33.5  46.0  38.950980   38.90

# %%
## map values MALE: m , FEMALE: f
df['sex'].head()

df['sex_new'] = df['sex'].map( {'MALE': 'm', 'FEMALE': 'f' } ).fillna('other')

df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex sex_new
# 0       3750.0    MALE       m
# 1       3800.0  FEMALE       f
# 2       3250.0  FEMALE       f
# 3          NaN     NaN   other
# 4       3450.0  FEMALE       f

# %%
## numpy: numerical python
import numpy as np

# %%
## pandas style
df['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
## numpy
np.mean(df['bill_length_mm'])
# Out:
# np.float64(43.9219298245614)

# %%
## other function of numpy
print(np.sum(df['bill_depth_mm']))
print(np.std(df['body_mass_g']))
# Out:
# 5865.700000000001
# 800.7812292384519

# %%
score = pd.Series([80, 55, 62, 95, 20])

# %%
print(score)
# Out:
# 0    80
# 1    55
# 2    62
# 3    95
# 4    20
# dtype: int64

# %%
score_status = np.where(score >= 80, 'passed', 'failed')
print(score_status)

for s, status in zip(score, score_status):
    # Print the score (s), a space, and the status
    print(f"{s} {status}")
# Out:
# ['passed' 'failed' 'failed' 'passed' 'failed']
# 80 passed
# 55 failed
# 62 failed
# 95 passed
# 20 failed

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex sex_new
# 0       3750.0    MALE       m
# 1       3800.0  FEMALE       f
# 2       3250.0  FEMALE       f
# 3          NaN     NaN   other
# 4       3450.0  FEMALE       f

# %%
mini_df = df.query(" species == 'Adelie' ")[['species', 'island', 'bill_length_mm']].dropna()

mini_df
# Out:
#     species     island  bill_length_mm
# 0    Adelie  Torgersen            39.1
# 1    Adelie  Torgersen            39.5
# 2    Adelie  Torgersen            40.3
# 4    Adelie  Torgersen            36.7
# 5    Adelie  Torgersen            39.3
# ..      ...        ...             ...
# 147  Adelie      Dream            36.6
# 148  Adelie      Dream            36.0
# 149  Adelie      Dream            37.8
# 150  Adelie      Dream            36.0
# 151  Adelie      Dream            41.5
#
# [151 rows x 3 columns]

# %%
mini_df['new_column'] = np.where(mini_df['bill_length_mm'] > 40, True, False)
mini_df.head(10)
# Out:
#    species     island  bill_length_mm  new_column
# 0   Adelie  Torgersen            39.1       False
# 1   Adelie  Torgersen            39.5       False
# 2   Adelie  Torgersen            40.3        True
# 4   Adelie  Torgersen            36.7       False
# 5   Adelie  Torgersen            39.3       False
# 6   Adelie  Torgersen            38.9       False
# 7   Adelie  Torgersen            39.2       False
# 8   Adelie  Torgersen            34.1       False
# 9   Adelie  Torgersen            42.0        True
# 10  Adelie  Torgersen            37.8       False

# %%
## merge dataframe -- (join data)
left = {
    'key': [1, 2, 3, 4],
    'name': ['ploy', 'joe', 'jane', 'anna'],
    'age': [20, 30, 40, 50]
}

right = {
    'key': [1, 2, 3, 4],
    'city': ['bangkok', 'london', 'paris', 'tokyo'],
    'zip': [1001, 2501, 2094, 9802]
}

df_left = pd.DataFrame(left)
df_right = pd.DataFrame(right)

# %%
df_left
# Out:
#    key  name  age
# 0    1  ploy   20
# 1    2   joe   30
# 2    3  jane   40
# 3    4  anna   50

# %%
df_right
# Out:
#    key     city   zip
# 0    1  bangkok  1001
# 1    2   london  2501
# 2    3    paris  2094
# 3    4    tokyo  9802

# %%
result = pd.merge(df_left, df_right, on='key')
result
# Out:
#    key  name  age     city   zip
# 0    1  ploy   20  bangkok  1001
# 1    2   joe   30   london  2501
# 2    3  jane   40    paris  2094
# 3    4  anna   50    tokyo  9802

# %%
import matplotlib.pyplot as plt

## create chart histogram one column
df['body_mass_g'].plot(kind='hist')
plt.title('body_mass_g')
plt.xlabel('Body Mass (g)') # Added x-axis label for clarity
plt.ylabel('Frequency') # Added y-axis label for clarity
plt.show() # Display the plot

# %%
## histogram two columns
df[['body_mass_g', 'bill_length_mm']].plot(kind='hist',bins=20, subplots=True, color=['salmon', 'blue']);

# %%
## bar plot for species
df['species'].value_counts().plot(kind='bar', color=['salmon', 'orange', 'gold']);

# %%
## scatter plot
df[['bill_length_mm', 'bill_depth_mm']].plot(x = 'bill_length_mm', y = 'bill_depth_mm', kind = 'scatter', color='salmon');
