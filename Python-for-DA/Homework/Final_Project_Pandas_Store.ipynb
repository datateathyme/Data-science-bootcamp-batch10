# %% [markdown]
# # 🐼 **Final Project - Analyzing Sales Data**
#
# Author: Chanakarn Chuklin
#
# Course: Pandas Foundation

# %%
## import library and data
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
## shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
## see dataframe information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# #### 🚀 **We can use pd.to_datetime() function to convert columns 'Order Date' and 'Ship Date' to datetime.**

# %%
## example of pd.to_datetime() function
pd.to_datetime(df['Order Date'].head(), format='%m/%d/%Y')
# Out:
# 0   2019-11-08
# 1   2019-11-08
# 2   2019-06-12
# 3   2018-10-11
# 4   2018-10-11
# Name: Order Date, dtype: datetime64[ns]

# %% [markdown]
# ### **#TODO** - convert order date and ship date to datetime in the original dataframe

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%m/%d/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %% [markdown]
# ### **#TODO** - count nan in postal code column

# %%
df['Postal Code'].isna().sum()
# Out:
# np.int64(11)

# %% [markdown]
# ### **#TODO** - filter rows with missing values

# %%
df.dropna()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3          4  US-2018-108966 2018-10-11 2018-10-18  Standard Class
# 4          5  US-2018-108966 2018-10-11 2018-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2017-110422 2017-01-21 2017-01-23    Second Class
# 9990    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 9991    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 9992    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 9993    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### **#TODO** - Explore this dataset on your owns, ask your own questions
#
# #### 🚀 Which Category of products generates the highest total Profit?

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11  Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
# 1   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
# Which Category of products generates the highest total Profit?
result = df.groupby('Category')['Profit'].sum().sort_values(ascending=False).reset_index().head(1)
result = round(result, 2)
result
# Out:
#      Category     Profit
# 0  Technology  145454.95

# %%
# What is the average Discount percentage offered to customers in each Segment?
df.groupby('Segment')['Discount'].mean().sort_values(ascending=False)
# Out:
# Segment
# Corporate      0.158228
# Consumer       0.158141
# Home Office    0.147128
# Name: Discount, dtype: float64

# %%
# Which are the top 5 regions based on total profit?
df.groupby('Region')['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %% [markdown]
# # 🐼 **Data Analysis Part**
#
# Answer 10 below questions to get credit from this course. Write pandas code to find answers.

# %% [markdown]
# ### **#TODO 01** - how many columns, rows in this dataset

# %%
df.shape # There are 9994 rows and 21 columns
# Out:
# (9994, 21)

# %% [markdown]
# ### **#TODO 02** - is there any missing values?, if there is, which colunm? how many nan values?

# %%
df.isna().sum() # column == 'Postal Code' == 11 values
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %% [markdown]
# ### **#TODO 03** - your friend ask for `California` data, filter it and export csv for him

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11  Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
# 1   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
## filter california data
california_data = df[ df['State'] == 'California' ]
california_data

## export csv
california_data.to_csv('california_data.csv', index=False)

# %% [markdown]
# ### **#TODO 04** - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11  Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11  Second Class    CG-12520
#
#   Customer Name   Segment Country/Region       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
# 1   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df['Order Year'] = df['Order Date'].dt.year

# %%
## filter data in california and texas in 2017
cal_tex_data = df[ (df['State'] == 'California') | (df['State'] == 'Texas') ]
cal_tex_data = cal_tex_data[ cal_tex_data['Order Year'] == 2017 ]
cal_tex_data

## export csv file
cal_tex_data.to_csv("california_texas_2017.csv", index=False)

# %%
cal_tex_data[['State', 'Order Year']].head()
# Out:
#         State  Order Year
# 5  California        2017
# 6  California        2017
# 7  California        2017
# 8  California        2017
# 9  California        2017

# %%
cal_tex_data[['State', 'Order Year']].tail()
# Out:
#            State  Order Year
# 9885  California        2017
# 9903       Texas        2017
# 9904       Texas        2017
# 9942  California        2017
# 9943  California        2017

# %%
cal_tex_data['State'].unique()
# Out:
# array(['California', 'Texas'], dtype=object)

# %% [markdown]
# ### **#TODO 05** - how much total sales, average sales, and standard deviation of sales your company make in 2017

# %%
sales_2017 = df[df['Order Year'] == 2017]['Sales']
sales_2017.describe()
# Out:
# count     1993.000000
# mean       242.974159
# std        754.053357
# min          0.852000
# 25%         16.224000
# 50%         51.968000
# 75%        218.750000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
sales_2017_2 = df[df['Order Year'] == 2017][['Sales', 'Order Year']]
sales_2017_2
# Out:
#         Sales  Order Year
# 5      48.860        2017
# 6       7.280        2017
# 7     907.152        2017
# 8      18.504        2017
# 9     114.900        2017
# ...       ...         ...
# 9946  151.200        2017
# 9956   46.350        2017
# 9957  223.920        2017
# 9958    7.300        2017
# 9989   25.248        2017
#
# [1993 rows x 2 columns]

# %%
sales_2017_2.groupby('Order Year')['Sales'].agg(['sum', 'mean', 'std'])
# Out:
#                     sum        mean         std
# Order Year
# 2017        484247.4981  242.974159  754.053357

# %% [markdown]
# ### **#TODO 06** - which Segment has the highest profit in 2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
df_2018 = df[ df['Order Year'] == 2018 ]

top_segment_2018 = df_2018.groupby('Segment')['Profit'].sum().sort_values(ascending=False)

top_segment_2018
# Out:
# Segment
# Consumer       28460.1665
# Corporate      20688.3248
# Home Office    12470.1124
# Name: Profit, dtype: float64

# %%
segment_highest_profit_2018 = df[df['Order Year'] == 2018].groupby('Segment')['Profit'].sum().sort_values(ascending=False).head(1)

segment_highest_profit_2018
# Out:
# Segment
# Consumer    28460.1665
# Name: Profit, dtype: float64

# %% [markdown]
# ### **#TODO 07** - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019

# %%
## filter date
filter_date = df[ (df['Order Date'] >= '2019-04-15') & (df['Order Date'] <= '2019-12-31') ]

filter_date = filter_date.sort_values(by='Order Date', ascending=True)

filter_date
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2252    2253  CA-2019-117849 2019-04-15 2019-04-17    Second Class
# 551      552  CA-2019-136406 2019-04-15 2019-04-17    Second Class
# 432      433  US-2019-123750 2019-04-15 2019-04-21  Standard Class
# 431      432  US-2019-123750 2019-04-15 2019-04-21  Standard Class
# 430      431  US-2019-123750 2019-04-15 2019-04-21  Standard Class
# ...      ...             ...        ...        ...             ...
# 4613    4614  US-2019-165953 2019-12-31 2020-01-06  Standard Class
# 4612    4613  US-2019-165953 2019-12-31 2020-01-06  Standard Class
# 2821    2822  CA-2019-100202 2019-12-31 2020-01-05  Standard Class
# 6341    6342  US-2019-105830 2019-12-31 2020-01-02     First Class
# 5738    5739  CA-2019-156139 2019-12-31 2020-01-06  Standard Class
#
#      Customer ID    Customer Name      Segment Country/Region           City  \
# 2252    JK-16120       Julie Kriz  Home Office  United States      San Diego
# ...

# %%
filter_date.groupby('State')['Sales'].sum().sort_values().head(5)
# Out:
# State
# New Hampshire            49.05
# New Mexico               64.08
# District of Columbia    117.07
# Louisiana               249.80
# South Carolina          502.48
# Name: Sales, dtype: float64

# %% [markdown]
# ### **#TODO 08** - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25%

# %%
df_2019 = df[ df['Order Year'] == 2019 ]
df_west_central_2019 = df_2019[ (df_2019['Region'] == 'West') | (df['Region'] == 'Central') ]

df_west_central_2019.head(2)
# Out:
# /tmp/ipython-input-1654954362.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_west_central_2019 = df_2019[ (df_2019['Region'] == 'West') | (df['Region'] == 'Central') ]
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2        3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 13      14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class    IM-15070
#
#       Customer Name    Segment Country/Region         City  ... Region  \
# 2   Darrin Van Huff  Corporate  United States  Los Angeles  ...   West
# 13     Irene Maddox   Consumer  United States      Seattle  ...   West
#
#          Product ID         Category Sub-Category  \
# 2   OFF-LA-10000240  Office Supplies       Labels
# 13  OFF-BI-10003656  Office Supplies      Binders
#
#                                          Product Name    Sales Quantity  \
# 2   Self-Adhesive Address Labels for Typewriters b...   14.620        2
# ...

# %%
## proportion of total sales (%)
result_prop = df_west_central_2019['Sales'].sum() / df_2019['Sales'].sum() * 100

result_prop = round(result_prop, 2)

print(result_prop, '%')
# Out:
# 54.97 %

# %% [markdown]
# ### **#TODO 09** - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020

# %%
df_2019_2020 = df[ (df['Order Year'] >= 2019) & (df['Order Year'] <= 2020) ]

df_2019_2020.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1        2  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2        3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 12      13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class    AA-10480
# 13      14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class    IM-15070
#
#       Customer Name    Segment Country/Region         City  ... Region  \
# 0       Claire Gute   Consumer  United States    Henderson  ...  South
# 1       Claire Gute   Consumer  United States    Henderson  ...  South
# 2   Darrin Van Huff  Corporate  United States  Los Angeles  ...   West
# 12     Andrew Allen   Consumer  United States      Concord  ...  South
# 13     Irene Maddox   Consumer  United States      Seattle  ...   West
#
#          Product ID         Category Sub-Category  \
# ...

# %%
# Top 10 popular products in terms of number of orders during 2019-2020
top_10_orders_2019_2020 = df_2019_2020.groupby('Product Name')['Order ID'].count().sort_values(ascending=False).head(10)

print("Top 10 Popular Products (Number of Orders) in 2019-2020:")
display(top_10_orders_2019_2020)
# Out:
# Top 10 Popular Products (Number of Orders) in 2019-2020:
# Product Name
# Easy-staple paper                                  27
# Staples                                            24
# Staple envelope                                    22
# Staples in misc. colors                            13
# Staple remover                                     12
# Storex Dura Pro Binders                            12
# Chromcraft Round Conference Tables                 12
# Avery Non-Stick Binders                            11
# Global Wood Trimmed Manager's Task Chair, Khaki    11
# Staple-based wall hangings                         10
# Name: Order ID, dtype: int64

# %%
# Top 10 popular products total sales
top_10_sales_2019_2020 = df_2019_2020.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_10_sales_2019_2020
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                 61599.824
# Hewlett Packard LaserJet 3310 Copier                  16079.732
# 3D Systems Cube Printer, 2nd Generation, Magenta      14299.890
# GBC Ibimaster 500 Manual ProClick Binding System      13621.542
# GBC DocuBind TL300 Electric Binding System            12737.258
# GBC DocuBind P400 Electric Binding System             12521.108
# Samsung Galaxy Mega 6.3                               12263.708
# HON 5400 Series Task Chairs for Big and Tall          11846.562
# Martin Yale Chadless Opener Electric Letter Opener    11825.902
# Global Troy Executive Leather Low-Back Tilter         10169.894
# Name: Sales, dtype: float64

# %% [markdown]
# ### **#TODO 10** - plot at least 2 plots, any plot you think interesting :)

# %%
import matplotlib.pyplot as plt

## bar plot
df['Segment'].value_counts().plot(kind='bar', color= ['salmon', 'orange', 'gold']);

plt.title('Segment Distribution')
plt.xlabel('Segment')
plt.ylabel('Count')
plt.show()

# %%
## pie plot
df['Category'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Category Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **#Bonus** - use np.where() to create new column in dataframe to help you answer your own questions

# %%
df.Profit.mean()
# Out:
# np.float64(28.65689630778467)

# %%
import numpy as np

df['High Profit'] = np.where(df['Profit'] > df.Profit.mean(), 'Yes', 'No')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 3       4  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 4       5  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...
